# %% [markdown]
# # Building the POI dataset
#
# The event siting tool uses points of interest (POI) data to indicate potential sites for their events.
#
# We use this notebook to demonstrate how we build an aggregate POI dataset from 4 sources:
# - OpenStreetMap POI data for Florida
# - OpenStreetMap Places of Worship (PofW) data for Florida
# - IRS 990N filings for 2022 for small nonprofits
# - IRS 990 filings for 2021 for large nonprofits
#
# ### Data sources
#
# - Florida OSM data was downloaded manually via [geofabrik](http://download.geofabrik.de/north-america/us/florida.html) and placed in `data/external`
#   - Warning: Raw unzipped data is 2.8GB
#   - Detailed layer descriptions are available from geofabrik at https://www.geofabrik.de/data/geofabrik-osm-gis-standard-0.7.pdf
# - IRS 990 and 990N data were downloaded from [irs.gov](https://www.irs.gov/charities-non-profits/form-990-series-downloads), parsed from XML format and geocoded separately, then placed in `data/interim`.
#
# The output file is saved to `data/interim/combined_pois.geojson`.

# %%
import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# Out:
# /Users/jtan/opt/anaconda3/envs/housd/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
# Set up data paths
DATA_DIR = "/Users/jtan/datakind/housd/data"

POI_PATH = os.path.join(DATA_DIR, "external", "florida-latest-free.shp", "gis_osm_pois_free_1.shp")

POFW_PATH = os.path.join(DATA_DIR, "external", "florida-latest-free.shp", "gis_osm_pofw_free_1.shp")

IRS990N_PATH = os.path.join(DATA_DIR, "interim", "fl_990n_addresses.csv")
IRS990N_GEO_PATH = os.path.join(DATA_DIR, "interim", "fl_990n_addresses_geocoded.csv")

IRS990_PATH = os.path.join(DATA_DIR, "interim", "IRS990_2021_mp_fl.csv")   
IRS990_GEO_PATH = os.path.join(DATA_DIR, "interim", "IRS990_2021_fl_geocoded.csv")

# %% [markdown]
# ## 1. Import data

# %%
pois = gpd.read_file(POI_PATH)

pois.head()
# Out:
#      osm_id  code        fclass                                     name  \
# 0  95855262  2422     camp_site                                     None
# 1  96919971  2724      memorial                                     None
# 2  97557631  2701  tourist_info                                   Mile 1
# 3  97571939  2007       library  Hardee Correctional Institution Library
# 4  98587924  2701  tourist_info                                     None
#
#                      geometry
# 0  POINT (-85.90703 30.23211)
# 1  POINT (-81.66089 30.32608)
# 2  POINT (-85.41047 29.80190)
# 3  POINT (-82.01485 27.59041)
# 4  POINT (-82.96365 29.50284)

# %%
pofw = gpd.read_file(POFW_PATH)

pofw.head()
# Out:
#       osm_id  code               fclass  \
# 0   99977221  3102   christian_catholic
# 1  282705754  3100            christian
# 2  283431303  3105  christian_methodist
# 3  286291955  3100            christian
# 4  286292175  3105  christian_methodist
#
#                                             name                    geometry
# 0                       Blessed Sacrament Church  POINT (-82.79883 27.83294)
# 1                                Crossing Church  POINT (-82.34436 27.92625)
# 2                 Keeney Chapel United Methodist  POINT (-82.36945 27.93942)
# 3  Progress Village Seventh-day Adventist Church  POINT (-82.36733 27.89468)
# 4                 Harris Temple United Methodist  POINT (-82.36657 27.89468)

# %%
irs_small = pd.read_csv(IRS990N_PATH)

irs_small.head()
# Out:
#    Unnamed: 0       EIN  Tax.Year                   Organization.Name  \
# 0        2458  10600708      2021     INTERIOR COVERINGS MINISTRY INC
# 1        2654  10621975      2021        ANGELA COURTE MINISTRIES INC
# 2        3403  10706390      2021  NATIONAL FEDERATION OF MUSIC CLUBS
# 3        3472  10716688      2021    ORLANDO KOREAN SENIOR CENTER INC
# 4        4422  10816505      2021  MISS RODEO FLORIDA ASSOCIATION INC
#
#   Gross.Receipts.Under.$25,000 Terminated Tax.Period.Begin.Date  \
# 0                            T          F            01-01-2021
# 1                            T          F            01-01-2021
# 2                            T          F            07-01-2021
# 3                            T          F            01-01-2021
# 4                            T          F            01-01-2021
#
#   Tax.Period.End.Date           Website.URL        Officer.Name  ...  \
# 0          12-31-2021                   NaN    AUDREY DRUMMONDS  ...
# 1          12-31-2021                   NaN    Angela Mackenzie  ...
# 2          06-30-2022  orlandomusicclub.org    Natalia Kalugina  ...
# 3          12-31-2021                   NaN             Alex Yi  ...
# 4          12-31-2021                   NaN  Frankie B Crawford  ...
#
#   Organization.Address.Line.1 Organization.Address.Line.2  \
# 0           18235 ROSE STREET                         NaN
# 1      272 West Cranes Circle                         NaN
# 2    303 East Highland Street                         NaN
# 3               506 ERICA WAY                         NaN
# 4          650 W Southport Rd                         NaN
#
#   Organization.Address.City Organization.Address.Province  \
# 0                 GROVELAND                           NaN
# 1         Altamonte Springs                           NaN
# 2         ALTAMONTE SPRINGS                           NaN
# 3            WINTER SPRINGS                           NaN
# 4                 Kissimmee                           NaN
#
#   Organization.Address.State  Organization.Address.Postal.Code  \
# 0                         FL                             34736
# 1                         FL                             32701
# 2                         FL                             32701
# 3                         FL                             32708
# 4                         FL                             32746
#
#   Organization.Address.Country Doing.Business.As.Name.1  \
# 0                           US                      NaN
# 1                           US                      NaN
# 2                           US                      NaN
# 3                           US                      NaN
# 4                           US                      NaN
#
#    Doing.Business.As.Name.2 Doing.Business.As.Name.3
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
#
# [5 rows x 27 columns]

# %%
irs_small_geo = pd.read_csv(IRS990N_GEO_PATH)

irs_small_geo.head()
# Out:
#    Unnamed: 0         id                                geocoded_address  \
# 0           0  263874780    The Congaloosh Society, Kissimmee, FL, 34758
# 1           1  202461223         901 Webster Ave, Winter Park, FL, 32789
# 2           2  260605478  5749 NORMAN H CUTSON DRIVE, Orlando, FL, 32821
# 3           3  203908198         3080 Zaharias Drive, ORLANDO, FL, 32837
# 4           4  263483237                 909 Enclair, Orlando, FL, 32828
#
#    is_match   is_exact                             returned_address  \
# 0  No_Match        NaN                                          NaN
# 1     Match  Non_Exact    901 W WEBSTER AVE, WINTER PARK, FL, 32789
# 2     Match      Exact  5749 NORMAN H CUTSON DR, ORLANDO, FL, 32821
# 3     Match      Exact         3080 ZAHARIAS DR, ORLANDO, FL, 32837
# 4     Match  Non_Exact           909 ENCLAIR ST, ORLANDO, FL, 32828
#
#                              coordinates   tiger_line side  state_fips  \
# 0                                    NaN          NaN  NaN         NaN
# 1  -81.36138890599995,28.603997374000073   94276948.0    R        12.0
# 2   -81.44954764099998,28.40610870300003   94335834.0    R        12.0
# 3   -81.41597000499996,28.36101755900006  617827390.0    R        12.0
# 4  -81.15631619499999,28.542850505000047  630991635.0    R        12.0
#
#    county_fips    tract   block       long        lat
# 0          NaN      NaN     NaN        NaN        NaN
# 1         95.0  15901.0  2007.0 -81.361389  28.603997
# 2         95.0  17026.0  1004.0 -81.449548  28.406109
# 3         95.0  17020.0  3000.0 -81.415970  28.361018
# 4         95.0  16748.0  1001.0 -81.156316  28.542851

# %%
irs_large = pd.read_csv(IRS990_PATH)

irs_large.head()
# Out:
#      org_ein                             org_name1       org_name2  \
# 0  650750873      THE MORTEZA-ZADEH FOUNDATION INC             NaN
# 1  204920710  PULICHINO TONG FAMILY FOUNDATION INC             NaN
# 2  815129308            Breathe 150 Conference Inc             NaN
# 3  452641647        SUNCOAST AQUATIC NATURE CENTER  ASSOCIATES INC
# 4  593622890              PURE WORD MINISTRIES INC             NaN
#
#            person_name     phone_num                       addr  \
# 0                  NaN           NaN     700 NORTH OLIVE AVENUE
# 1                  NaN  5.614414e+09          2981 W MCNAB ROAD
# 2     % Tracey Council  7.572771e+09          1315 Sand Lime Rd
# 3                  NaN  9.413587e+09  5851 NATHAN BENDERSON CIR
# 4  % Richard J Perkins           NaN         2626 SUNNYSIDE CIR
#
#               city state        zip            officer_name  \
# 0  WEST PALM BEACH    FL      33401                     NaN
# 1    POMPANO BEACH    FL  330694804                     NaN
# 2    Winter Garden    FL      34787                     NaN
# 3         SARASOTA    FL      34235  THOMAS HERRERA-MISHLER
# 4      PALM HARBOR    FL  346844159                     NaN
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3  WWW.NATHANBENDERSONPARK.ORG
# 4                          NaN
#
#                                              mission
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  THE ORGANIZATION'S PRIMARY PURPOSE IS TO MANAG...
# 4                                                NaN

# %%
irs_large_geo = pd.read_csv(IRS990_GEO_PATH)

irs_large_geo.head()
# Out:
#           id                                   geocoded_address  is_match  \
# 0  526027312                PO BOX 1908, ORLANDO, FL, 328021908  No_Match
# 1  223700343     570 OCEAN DRIVE NO 1101, JUNO BEACH, FL, 33408     Match
# 2  137529459   471 NORTH ARROWHEAD TRAIL, VERO BEACH, FL, 32963     Match
# 3  465314273  200 W COLLEGE AVENUE NO 210, TALLAHASSEE, FL, ...  No_Match
# 4  596178235             803 EYRIE DRIVE 101, OVIEDO, FL, 32765     Match
#
#     is_exact                            returned_address  \
# 0        NaN                                         NaN
# 1  Non_Exact         570 OCEAN DR, JUNO BEACH, FL, 33408
# 2      Exact  471 N ARROWHEAD TRL, VERO BEACH, FL, 32963
# 3        NaN                                         NaN
# 4      Exact             803 EYRIE DR, OVIEDO, FL, 32765
#
#                              coordinates   tiger_line side  state_fips  \
# 0                                    NaN          NaN  NaN         NaN
# 1  -80.05262499199995,26.875237423000044  115507480.0    R        12.0
# 2  -80.38898884799994,27.740958351000074  120326359.0    L        12.0
# 3                                    NaN          NaN  NaN         NaN
# 4  -81.22313752499997,28.658404939000036   93746631.0    L        12.0
#
#    county_fips    tract   block       long        lat
# 0          NaN      NaN     NaN        NaN        NaN
# 1         99.0    410.0  3001.0 -80.052625  26.875237
# 2         61.0  50506.0  2002.0 -80.388989  27.740958
# 3          NaN      NaN     NaN        NaN        NaN
# 4        117.0  21314.0  3022.0 -81.223138  28.658405

# %% [markdown]
# ## 2. Transform datasets to fit a common schema
#
# The final POI dataset will have the following schema:
# - id
# - name: name of the location
# - type: the type of location this is
# - geometry: a shapely Point object
# - source: where the data came from

# %% [markdown]
# ### 2.1 POI data

# %%
pois.columns
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')

# %%
# Create crosswalk between old and new column names
cols_to_keep = {
    "osm_id": "id",
    "name": "name",
    "fclass": "type",
    "geometry": "geometry"
}

pois = pois[cols_to_keep.keys()].rename(columns=cols_to_keep)
pois["source"] = "openstreetmap"

pois.head()
# Out:
#          id                                     name          type  \
# 0  95855262                                     None     camp_site
# 1  96919971                                     None      memorial
# 2  97557631                                   Mile 1  tourist_info
# 3  97571939  Hardee Correctional Institution Library       library
# 4  98587924                                     None  tourist_info
#
#                      geometry         source
# 0  POINT (-85.90703 30.23211)  openstreetmap
# 1  POINT (-81.66089 30.32608)  openstreetmap
# 2  POINT (-85.41047 29.80190)  openstreetmap
# 3  POINT (-82.01485 27.59041)  openstreetmap
# 4  POINT (-82.96365 29.50284)  openstreetmap

# %% [markdown]
# ### 2.2 PofW data

# %%
pofw.columns
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')

# %%
# Create crosswalk between old and new column names
cols_to_keep = {
    "osm_id": "id",
    "name": "name",
    "fclass": "type",
    "geometry": "geometry"
}

pofw = pofw[cols_to_keep.keys()].rename(columns=cols_to_keep)

pofw["type"] = "place_of_worship"
pofw["source"] = "openstreetmap"

pofw.head()
# Out:
#           id                                           name              type  \
# 0   99977221                       Blessed Sacrament Church  place_of_worship
# 1  282705754                                Crossing Church  place_of_worship
# 2  283431303                 Keeney Chapel United Methodist  place_of_worship
# 3  286291955  Progress Village Seventh-day Adventist Church  place_of_worship
# 4  286292175                 Harris Temple United Methodist  place_of_worship
#
#                      geometry         source
# 0  POINT (-82.79883 27.83294)  openstreetmap
# 1  POINT (-82.34436 27.92625)  openstreetmap
# 2  POINT (-82.36945 27.93942)  openstreetmap
# 3  POINT (-82.36733 27.89468)  openstreetmap
# 4  POINT (-82.36657 27.89468)  openstreetmap

# %% [markdown]
# ### 2.3 IRS 990N data (`irs_small`)

# %%
# Create geodataframe of shapely Points from lat-long 
irs_small_gdf = gpd.GeoDataFrame(
    irs_small, 
    geometry=gpd.points_from_xy(irs_small_geo.long, irs_small_geo.lat)
).set_crs(4326)

irs_small_gdf.head()
# Out:
#    Unnamed: 0       EIN  Tax.Year                   Organization.Name  \
# 0        2458  10600708      2021     INTERIOR COVERINGS MINISTRY INC
# 1        2654  10621975      2021        ANGELA COURTE MINISTRIES INC
# 2        3403  10706390      2021  NATIONAL FEDERATION OF MUSIC CLUBS
# 3        3472  10716688      2021    ORLANDO KOREAN SENIOR CENTER INC
# 4        4422  10816505      2021  MISS RODEO FLORIDA ASSOCIATION INC
#
#   Gross.Receipts.Under.$25,000 Terminated Tax.Period.Begin.Date  \
# 0                            T          F            01-01-2021
# 1                            T          F            01-01-2021
# 2                            T          F            07-01-2021
# 3                            T          F            01-01-2021
# 4                            T          F            01-01-2021
#
#   Tax.Period.End.Date           Website.URL        Officer.Name  ...  \
# 0          12-31-2021                   NaN    AUDREY DRUMMONDS  ...
# 1          12-31-2021                   NaN    Angela Mackenzie  ...
# 2          06-30-2022  orlandomusicclub.org    Natalia Kalugina  ...
# 3          12-31-2021                   NaN             Alex Yi  ...
# 4          12-31-2021                   NaN  Frankie B Crawford  ...
#
#   Organization.Address.Line.2 Organization.Address.City  \
# 0                         NaN                 GROVELAND
# 1                         NaN         Altamonte Springs
# 2                         NaN         ALTAMONTE SPRINGS
# 3                         NaN            WINTER SPRINGS
# 4                         NaN                 Kissimmee
#
#   Organization.Address.Province Organization.Address.State  \
# 0                           NaN                         FL
# 1                           NaN                         FL
# 2                           NaN                         FL
# 3                           NaN                         FL
# 4                           NaN                         FL
#
#   Organization.Address.Postal.Code  Organization.Address.Country  \
# 0                            34736                            US
# 1                            32701                            US
# 2                            32701                            US
# 3                            32708                            US
# 4                            32746                            US
#
#   Doing.Business.As.Name.1 Doing.Business.As.Name.2  Doing.Business.As.Name.3  \
# 0                      NaN                      NaN                       NaN
# 1                      NaN                      NaN                       NaN
# 2                      NaN                      NaN                       NaN
# 3                      NaN                      NaN                       NaN
# 4                      NaN                      NaN                       NaN
#
#                      geometry
# 0                 POINT EMPTY
# 1  POINT (-81.36139 28.60400)
# 2  POINT (-81.44955 28.40611)
# 3  POINT (-81.41597 28.36102)
# 4  POINT (-81.15632 28.54285)
#
# [5 rows x 28 columns]

# %%
# Create crosswalk between old and new column names
cols_to_keep = {
    "EIN": "id", 
    "Organization.Name": "name",
    "geometry": "geometry"
}

# Drop NAs 
irs_small_gdf = irs_small_gdf[~irs_small_geo.lat.isna()]

# Apply crosswalk
irs_small_gdf = irs_small_gdf[cols_to_keep.keys()].rename(columns=cols_to_keep)

# Create "type" and "source" column
irs_small_gdf["type"] = "nonprofit"
irs_small_gdf["source"] = "IRS 990N"

irs_small_gdf.head()
# Out:
#          id                                name                    geometry  \
# 1  10621975        ANGELA COURTE MINISTRIES INC  POINT (-81.36139 28.60400)
# 2  10706390  NATIONAL FEDERATION OF MUSIC CLUBS  POINT (-81.44955 28.40611)
# 3  10716688    ORLANDO KOREAN SENIOR CENTER INC  POINT (-81.41597 28.36102)
# 4  10816505  MISS RODEO FLORIDA ASSOCIATION INC  POINT (-81.15632 28.54285)
# 6  10877308              SHRINERS INTERNATIONAL  POINT (-80.80127 28.55893)
#
#         type    source
# 1  nonprofit  IRS 990N
# 2  nonprofit  IRS 990N
# 3  nonprofit  IRS 990N
# 4  nonprofit  IRS 990N
# 6  nonprofit  IRS 990N

# %% [markdown]
# ### 2.4 IRS 990 data (`irs_large`)

# %%
# Drop NAs
irs_large_geo = irs_large_geo[~irs_large_geo.lat.isna()]

# Create geodataframe of shapely Points from lat-long 
irs_large_gdf = gpd.GeoDataFrame(
    irs_large_geo, 
    geometry=gpd.points_from_xy(irs_large_geo.long, irs_large_geo.lat)
).set_crs(4326)

irs_large_gdf.head()
# Out:
#           id                                   geocoded_address is_match  \
# 1  223700343     570 OCEAN DRIVE NO 1101, JUNO BEACH, FL, 33408    Match
# 2  137529459   471 NORTH ARROWHEAD TRAIL, VERO BEACH, FL, 32963    Match
# 4  596178235             803 EYRIE DRIVE 101, OVIEDO, FL, 32765    Match
# 7  592174510      6401 Lyons Road, Coconut Creek, FL, 330733602    Match
# 9  592244943  3160 Southgate Commerce Blvd Suite, Orlando, F...    Match
#
#     is_exact                                  returned_address  \
# 1  Non_Exact               570 OCEAN DR, JUNO BEACH, FL, 33408
# 2      Exact        471 N ARROWHEAD TRL, VERO BEACH, FL, 32963
# 4      Exact                   803 EYRIE DR, OVIEDO, FL, 32765
# 7      Exact           6401 LYONS RD, COCONUT CREEK, FL, 33073
# 9      Exact  3160 SOUTHGATE COMMERCE BLVD, ORLANDO, FL, 32806
#
#                              coordinates   tiger_line side  state_fips  \
# 1  -80.05262499199995,26.875237423000044  115507480.0    R        12.0
# 2  -80.38898884799994,27.740958351000074  120326359.0    L        12.0
# 4  -81.22313752499997,28.658404939000036   93746631.0    L        12.0
# 7  -80.18657224699996,26.298654316000068  114798550.0    R        12.0
# 9   -81.37714689099994,28.50756628700003  641064641.0    L        12.0
#
#    county_fips    tract   block       long        lat  \
# 1         99.0    410.0  3001.0 -80.052625  26.875237
# 2         61.0  50506.0  2002.0 -80.388989  27.740958
# 4        117.0  21314.0  3022.0 -81.223138  28.658405
# 7         11.0  10606.0  1000.0 -80.186572  26.298654
# 9         95.0  13900.0  1019.0 -81.377147  28.507566
#
#                      geometry
# 1  POINT (-80.05262 26.87524)
# 2  POINT (-80.38899 27.74096)
# 4  POINT (-81.22314 28.65840)
# 7  POINT (-80.18657 26.29865)
# 9  POINT (-81.37715 28.50757)

# %%
# Create crosswalk between old and new column names
cols_to_keep = {
    "org_ein": "id",
    "org_name1": "name",
    "geometry": "geometry"
}

# Merge on geo data, filter and rename columns
irs_large_gdf = irs_large.merge(irs_large_gdf, how="inner", left_on="org_ein", right_on="id") \
    [cols_to_keep.keys()] \
    .rename(columns=cols_to_keep)

# Create "type" and "source" column
irs_large_gdf["type"] = "nonprofit"
irs_large_gdf["source"] = "IRS 990"

irs_large_gdf.head()
# Out:
#           id                                     name  \
# 0  650750873         THE MORTEZA-ZADEH FOUNDATION INC
# 1  204920710     PULICHINO TONG FAMILY FOUNDATION INC
# 2  815129308               Breathe 150 Conference Inc
# 3  593622890                 PURE WORD MINISTRIES INC
# 4  387193282  MARK & EILEEN EPSTEIN FAMILY CHARITABLE
#
#                      geometry       type   source
# 0  POINT (-80.05177 26.71895)  nonprofit  IRS 990
# 1  POINT (-80.18108 26.20917)  nonprofit  IRS 990
# 2  POINT (-81.59647 28.54708)  nonprofit  IRS 990
# 3  POINT (-82.72892 28.05746)  nonprofit  IRS 990
# 4  POINT (-80.27637 25.32272)  nonprofit  IRS 990

# %% [markdown]
# ## 3. Combine all datasets

# %%
datasets = [pois, pofw, irs_small_gdf, irs_large_gdf]

all_pois = pd.concat(datasets)

all_pois.head()
# Out:
#          id                                     name          type  \
# 0  95855262                                     None     camp_site
# 1  96919971                                     None      memorial
# 2  97557631                                   Mile 1  tourist_info
# 3  97571939  Hardee Correctional Institution Library       library
# 4  98587924                                     None  tourist_info
#
#                      geometry         source
# 0  POINT (-85.90703 30.23211)  openstreetmap
# 1  POINT (-81.66089 30.32608)  openstreetmap
# 2  POINT (-85.41047 29.80190)  openstreetmap
# 3  POINT (-82.01485 27.59041)  openstreetmap
# 4  POINT (-82.96365 29.50284)  openstreetmap

# %% [markdown]
# ## 4. Save data

# %%
OUTPUT_PATH = os.path.join(DATA_DIR, "interim", "combined_pois.geojson")

all_pois.to_file(OUTPUT_PATH, driver="GeoJSON")
# Out:
# /Users/jtan/opt/anaconda3/envs/housd/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
